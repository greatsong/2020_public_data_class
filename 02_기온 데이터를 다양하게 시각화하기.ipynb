# %%
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        result.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.figure(figsize = (10,2), dpi = 300)
plt.plot(result, 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %%
import random
print(random.randint(1,6))
# Out:
# 2

# %%
import random
for i in range(5) :
    print(random.randint(1,6))
# Out:
# 3
# 6
# 1
# 2
# 1

# %%
import random
dice = []
for i in range(5) :
    dice.append(random.randint(1,6))
print(dice)
# Out:
# [6, 4, 3, 4, 5]

# %%
import random
dice = []
for i in range(5) :
    dice.append(random.randint(1,6))
print(dice)

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.hist(dice, bins = 6)
plt.show()
# Out:
# [3, 3, 4, 5, 1]

# %%
import random
dice = []
for i in range(100) :
    dice.append(random.randint(1,6))
print(dice)

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.hist(dice, bins = 6)
plt.show()
# Out:
# [2, 6, 1, 6, 4, 4, 4, 6, 5, 4, 6, 2, 3, 4, 4, 5, 5, 1, 3, 6, 4, 6, 3, 1, 3, 5, 1, 1, 2, 5, 4, 1, 3, 2, 1, 3, 3, 1, 2, 1, 5, 3, 3, 5, 4, 1, 5, 2, 5, 6, 5, 5, 3, 1, 2, 3, 6, 4, 1, 5, 4, 3, 2, 6, 1, 1, 4, 1, 3, 6, 2, 6, 6, 3, 1, 2, 6, 5, 6, 6, 2, 3, 3, 2, 6, 3, 5, 6, 3, 2, 5, 2, 2, 5, 5, 2, 3, 2, 4, 5]

# %%
import random
dice = []
for i in range(100) :
    dice.append(random.randint(1,6))
print(dice)

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.hist(dice, bins = 6)
plt.show()
# Out:
# [1, 1, 1, 6, 1, 5, 3, 1, 5, 5, 3, 4, 3, 2, 2, 6, 3, 4, 2, 4, 2, 4, 3, 1, 2, 5, 4, 5, 5, 4, 1, 6, 5, 5, 6, 2, 5, 2, 5, 4, 1, 5, 5, 2, 1, 5, 1, 6, 3, 1, 1, 5, 3, 4, 2, 4, 2, 5, 2, 5, 6, 4, 2, 6, 6, 5, 6, 4, 1, 5, 4, 5, 5, 3, 2, 3, 4, 4, 2, 1, 2, 5, 4, 5, 4, 4, 1, 2, 1, 3, 4, 5, 5, 2, 4, 1, 4, 2, 3, 4]

# %%
import random
dice = []
for i in range(1000000) :
    dice.append(random.randint(1,6))

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.hist(dice, bins = 6)
plt.show()

# %%
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        result.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.hist(result, bins = 100, color = 'r')
plt.show()

# %%
plt.figure(dpi = 300)
plt.hist(result, bins = 1000, color = 'r')
plt.show()

# %%
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)
aug = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.hist(aug, bins = 100, color = 'r')
plt.show()

# %%
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.hist(aug, bins = 100, color = 'r', label = 'Aug')
plt.hist(jan, bins = 100, color = 'b', label = 'Jan')
plt.legend()
plt.show()

# %%
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)
aug = []
jul = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))
        if month == '07':
            jul.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.hist(aug, bins = 100, color = 'r', label = 'Aug', alpha = 0.3)
plt.hist(jul, bins = 100, color = 'magenta', label = 'Jul', alpha = 0.3)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(dpi = 300)
import random
result = []
for i in range(13) :
    result.append(random.randint(1,1000))
print(sorted(result))
import numpy as np
result = np.array(result)
print("1/4: " + str(np.percentile(result,25)))
print("2/4: " + str(np.percentile(result,50)))
print("3/4: " + str(np.percentile(result,75)))
plt.boxplot(result)
plt.show()
# Out:
# [185, 219, 249, 331, 376, 379, 393, 537, 608, 635, 647, 751, 923]
# 1/4: 331.0
# 2/4: 393.0
# 3/4: 635.0

# %%
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        result.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.boxplot(result)
plt.show()

# %%
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.boxplot(aug)
plt.boxplot(jan)
plt.show()

# %%
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.boxplot([aug,jan])
plt.show()

# %%
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.figure(dpi = 300)
plt.style.use('ggplot')
plt.boxplot([aug,jan], showfliers=False)
plt.xticks((1,2), ['Aug','Jan'])
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)
month = [[],[],[],[],[],[],[],[],[],[],[],[]]

for row in data :
    if row[-1] != '' :
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))
        
plt.figure(figsize=(10,5), dpi=300)
plt.boxplot(month)
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)

day = []
for i in range(31) : 
    day.append([])

for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '08':
            day[int(row[0].split('-')[2])-1].append(float(row[-1]))
        
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.boxplot(day, showfliers=False)
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
next(data)

day = [[] for i in range(31)]

for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '08':
            day[int(row[0].split('-')[2])-1].append(float(row[-1]))
        
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.boxplot(day, showfliers=False)
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
f = open('seoul_temp.csv')
data = csv.reader(f)
month = [[],[],[],[],[],[],[],[],[],[],[],[]]
next(data)
for row in data :
    if row[-1] != '' and row[-2] != '' :
        month[int(row[0].split('-')[1])-1].append(float(row[-1]) - float(row[-2]))

plt.style.use('ggplot')
plt.figure(figsize=(10,3), dpi=300)
plt.boxplot(month, showfliers=False)
plt.show()
